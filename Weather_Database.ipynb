# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
from datetime import datetime
import requests
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
longs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats,longs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 590

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=98e9838d49085ee90436d956ca470479

# %%
# Create an empty list to hold the weather data of cities
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kahului
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | mount gambier
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | skiros
# City not found. Skipping...
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | faanui
# Processing Record 11 of Set 1 | hamilton
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | hambantota
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | baker city
# Processing Record 21 of Set 1 | vershino-darasunskiy
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | cardenas
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | christchurch
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | mao
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | rawson
# Processing Record 30 of Set 1 | san quintin
# Processing Record 31 of Set 1 | avera
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | lalmohan
# Processing Record 34 of Set 1 | kalmar
# Processing Record 35 of Set 1 | pisco
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | paamiut
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | lesnoye
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | mamlyutka
# Processing Record 47 of Set 1 | mapiri
# Processing Record 48 of Set 1 | aksay
# Processing Record 49 of Set 1 | namibe
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | acapulco
# Processing Record 2 of Set 2 | manaure
# Processing Record 3 of Set 2 | kamenka
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | touros
# Processing Record 6 of Set 2 | khani
# Processing Record 7 of Set 2 | caravelas
# Processing Record 8 of Set 2 | aklavik
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | sisimiut
# Processing Record 11 of Set 2 | kavaratti
# Processing Record 12 of Set 2 | gwadar
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | xichang
# Processing Record 15 of Set 2 | zyryanka
# Processing Record 16 of Set 2 | shimoda
# Processing Record 17 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | byron bay
# Processing Record 21 of Set 2 | uglegorsk
# Processing Record 22 of Set 2 | provideniya
# Processing Record 23 of Set 2 | beringovskiy
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | tura
# Processing Record 26 of Set 2 | san patricio
# Processing Record 27 of Set 2 | haimen
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | vardo
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | thung song
# Processing Record 32 of Set 2 | coihaique
# Processing Record 33 of Set 2 | aksu
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | mandeville
# Processing Record 37 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 2 | asau
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 2 | champerico
# Processing Record 42 of Set 2 | lewiston
# Processing Record 43 of Set 2 | xingcheng
# Processing Record 44 of Set 2 | calama
# Processing Record 45 of Set 2 | talnakh
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | luderitz
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | taksimo
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | poronaysk
# Processing Record 3 of Set 3 | te anau
# Processing Record 4 of Set 3 | la ronge
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | san blas
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | saint george
# Processing Record 10 of Set 3 | midland
# Processing Record 11 of Set 3 | vung tau
# Processing Record 12 of Set 3 | port hardy
# Processing Record 13 of Set 3 | auki
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | kloulklubed
# Processing Record 16 of Set 3 | bonavista
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | roma
# Processing Record 19 of Set 3 | salalah
# Processing Record 20 of Set 3 | alofi
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | tulum
# Processing Record 24 of Set 3 | harer
# Processing Record 25 of Set 3 | mar del plata
# Processing Record 26 of Set 3 | brainerd
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | ahipara
# Processing Record 30 of Set 3 | dovbysh
# Processing Record 31 of Set 3 | buin
# Processing Record 32 of Set 3 | narsaq
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | veshkayma
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | epe
# Processing Record 37 of Set 3 | bengkulu
# Processing Record 38 of Set 3 | pevek
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | hauterive
# Processing Record 41 of Set 3 | deputatskiy
# Processing Record 42 of Set 3 | sitka
# Processing Record 43 of Set 3 | camacha
# Processing Record 44 of Set 3 | lasa
# Processing Record 45 of Set 3 | lac du bonnet
# Processing Record 46 of Set 3 | belyy yar
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | panzhihua
# Processing Record 49 of Set 3 | broken hill
# Processing Record 50 of Set 3 | salinopolis
# Processing Record 1 of Set 4 | gizo
# Processing Record 2 of Set 4 | henties bay
# Processing Record 3 of Set 4 | hualmay
# Processing Record 4 of Set 4 | kabinda
# Processing Record 5 of Set 4 | patrocinio
# Processing Record 6 of Set 4 | macapa
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | gaya
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | constitucion
# Processing Record 12 of Set 4 | saint-georges
# Processing Record 13 of Set 4 | vila franca do campo
# Processing Record 14 of Set 4 | codrington
# Processing Record 15 of Set 4 | banda aceh
# Processing Record 16 of Set 4 | tres arroyos
# Processing Record 17 of Set 4 | dubbo
# Processing Record 18 of Set 4 | kaeo
# Processing Record 19 of Set 4 | matara
# Processing Record 20 of Set 4 | rincon
# Processing Record 21 of Set 4 | berlevag
# Processing Record 22 of Set 4 | dahra
# Processing Record 23 of Set 4 | leningradskiy
# Processing Record 24 of Set 4 | port hedland
# Processing Record 25 of Set 4 | dikson
# Processing Record 26 of Set 4 | los llanos de aridane
# Processing Record 27 of Set 4 | lahaina
# Processing Record 28 of Set 4 | puerto leguizamo
# Processing Record 29 of Set 4 | kampene
# Processing Record 30 of Set 4 | kruisfontein
# Processing Record 31 of Set 4 | jiangyou
# Processing Record 32 of Set 4 | haines junction
# Processing Record 33 of Set 4 | ilabaya
# Processing Record 34 of Set 4 | linxia
# Processing Record 35 of Set 4 | nicoya
# Processing Record 36 of Set 4 | saskylakh
# Processing Record 37 of Set 4 | kirakira
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | faya
# Processing Record 40 of Set 4 | lata
# Processing Record 41 of Set 4 | kapaa
# Processing Record 42 of Set 4 | marsa matruh
# Processing Record 43 of Set 4 | yuli
# Processing Record 44 of Set 4 | adrar
# Processing Record 45 of Set 4 | gamba
# Processing Record 46 of Set 4 | coahuayana
# Processing Record 47 of Set 4 | ambulu
# Processing Record 48 of Set 4 | hokitika
# Processing Record 49 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 4 | hurup
# Processing Record 1 of Set 5 | pathein
# Processing Record 2 of Set 5 | conceicao da barra
# Processing Record 3 of Set 5 | homer
# Processing Record 4 of Set 5 | severo-kurilsk
# Processing Record 5 of Set 5 | kurilsk
# Processing Record 6 of Set 5 | ugoofaaru
# Processing Record 7 of Set 5 | bairiki
# Processing Record 8 of Set 5 | dinard
# Processing Record 9 of Set 5 | pak phanang
# Processing Record 10 of Set 5 | bouca
# Processing Record 11 of Set 5 | kuusamo
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | nelson bay
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | severnyy
# Processing Record 16 of Set 5 | teguldet
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | chernyshevskiy
# Processing Record 19 of Set 5 | samarai
# Processing Record 20 of Set 5 | erdaojiang
# Processing Record 21 of Set 5 | ahvaz
# Processing Record 22 of Set 5 | mansa
# Processing Record 23 of Set 5 | iracoubo
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | mariental
# Processing Record 26 of Set 5 | chifeng
# Processing Record 27 of Set 5 | carballo
# Processing Record 28 of Set 5 | aporawan
# City not found. Skipping...
# Processing Record 29 of Set 5 | dhariwal
# Processing Record 30 of Set 5 | hendijan
# City not found. Skipping...
# Processing Record 31 of Set 5 | tessalit
# Processing Record 32 of Set 5 | morondava
# Processing Record 33 of Set 5 | durban
# Processing Record 34 of Set 5 | mwingi
# Processing Record 35 of Set 5 | bagan
# Processing Record 36 of Set 5 | aleksandrovskoye
# Processing Record 37 of Set 5 | rudnichnyy
# Processing Record 38 of Set 5 | jibuti
# Processing Record 39 of Set 5 | rio gallegos
# Processing Record 40 of Set 5 | maldonado
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | chitipa
# Processing Record 43 of Set 5 | hanmer springs
# Processing Record 44 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 5 | valparaiso
# Processing Record 46 of Set 5 | dedougou
# Processing Record 47 of Set 5 | labuhan
# Processing Record 48 of Set 5 | lexington
# Processing Record 49 of Set 5 | komsomolskiy
# Processing Record 50 of Set 5 | high level
# Processing Record 1 of Set 6 | tuatapere
# Processing Record 2 of Set 6 | kununurra
# Processing Record 3 of Set 6 | broome
# Processing Record 4 of Set 6 | hellvik
# Processing Record 5 of Set 6 | georgetown
# Processing Record 6 of Set 6 | rosetta
# Processing Record 7 of Set 6 | honiara
# Processing Record 8 of Set 6 | noumea
# Processing Record 9 of Set 6 | chuy
# Processing Record 10 of Set 6 | grindavik
# Processing Record 11 of Set 6 | pskov
# Processing Record 12 of Set 6 | santa lucia
# Processing Record 13 of Set 6 | viesca
# Processing Record 14 of Set 6 | jamestown
# Processing Record 15 of Set 6 | ambanja
# Processing Record 16 of Set 6 | leiyang
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | santa cruz
# Processing Record 19 of Set 6 | kodinsk
# Processing Record 20 of Set 6 | punta alta
# Processing Record 21 of Set 6 | nouadhibou
# Processing Record 22 of Set 6 | cherskiy
# Processing Record 23 of Set 6 | saldanha
# Processing Record 24 of Set 6 | mahibadhoo
# Processing Record 25 of Set 6 | cidreira
# Processing Record 26 of Set 6 | kohlu
# Processing Record 27 of Set 6 | yumen
# Processing Record 28 of Set 6 | vallenar
# Processing Record 29 of Set 6 | pasighat
# Processing Record 30 of Set 6 | okhotsk
# Processing Record 31 of Set 6 | baboua
# City not found. Skipping...
# Processing Record 32 of Set 6 | yarada
# Processing Record 33 of Set 6 | hay river
# Processing Record 34 of Set 6 | san policarpo
# Processing Record 35 of Set 6 | treinta y tres
# Processing Record 36 of Set 6 | sorland
# Processing Record 37 of Set 6 | liverpool
# Processing Record 38 of Set 6 | marang
# Processing Record 39 of Set 6 | champaign
# Processing Record 40 of Set 6 | ponta do sol
# Processing Record 41 of Set 6 | sunndalsora
# Processing Record 42 of Set 6 | bilma
# Processing Record 43 of Set 6 | ostrovnoy
# Processing Record 44 of Set 6 | indramayu
# Processing Record 45 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 6 | kargasok
# Processing Record 47 of Set 6 | bria
# Processing Record 48 of Set 6 | port blair
# Processing Record 49 of Set 6 | weligama
# Processing Record 50 of Set 6 | huitzuco
# City not found. Skipping...
# Processing Record 1 of Set 7 | argir
# Processing Record 2 of Set 7 | dekoa
# City not found. Skipping...
# Processing Record 3 of Set 7 | fortuna
# Processing Record 4 of Set 7 | nizhniy tsasuchey
# Processing Record 5 of Set 7 | nagorsk
# Processing Record 6 of Set 7 | pozo colorado
# Processing Record 7 of Set 7 | tommot
# Processing Record 8 of Set 7 | souillac
# Processing Record 9 of Set 7 | rovaniemi
# Processing Record 10 of Set 7 | ipubi
# Processing Record 11 of Set 7 | vestmannaeyjar
# Processing Record 12 of Set 7 | longyearbyen
# Processing Record 13 of Set 7 | norman wells
# Processing Record 14 of Set 7 | bantry
# Processing Record 15 of Set 7 | nishihara
# Processing Record 16 of Set 7 | boende
# Processing Record 17 of Set 7 | hofn
# Processing Record 18 of Set 7 | yulara
# Processing Record 19 of Set 7 | walvis bay
# Processing Record 20 of Set 7 | ballina
# Processing Record 21 of Set 7 | fairbanks
# Processing Record 22 of Set 7 | yellowknife
# Processing Record 23 of Set 7 | japura
# Processing Record 24 of Set 7 | tarbes
# Processing Record 25 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 7 | peniche
# Processing Record 27 of Set 7 | fort saint james
# Processing Record 28 of Set 7 | maceio
# Processing Record 29 of Set 7 | geraldton
# Processing Record 30 of Set 7 | emba
# Processing Record 31 of Set 7 | college
# Processing Record 32 of Set 7 | iki-burul
# Processing Record 33 of Set 7 | rio cuarto
# Processing Record 34 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 7 | mazyr
# Processing Record 36 of Set 7 | hit
# Processing Record 37 of Set 7 | pangnirtung
# Processing Record 38 of Set 7 | wanning
# Processing Record 39 of Set 7 | boa vista
# Processing Record 40 of Set 7 | mizan teferi
# Processing Record 41 of Set 7 | hassleholm
# Processing Record 42 of Set 7 | newton
# Processing Record 43 of Set 7 | doctor arroyo
# Processing Record 44 of Set 7 | umm kaddadah
# Processing Record 45 of Set 7 | vestmanna
# Processing Record 46 of Set 7 | pyay
# Processing Record 47 of Set 7 | amboasary
# Processing Record 48 of Set 7 | magdagachi
# Processing Record 49 of Set 7 | pishin
# Processing Record 50 of Set 7 | zhigalovo
# Processing Record 1 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 8 | atar
# Processing Record 4 of Set 8 | san jose de rio tinto
# Processing Record 5 of Set 8 | nuuk
# Processing Record 6 of Set 8 | qingdao
# Processing Record 7 of Set 8 | ancud
# Processing Record 8 of Set 8 | marsh harbour
# Processing Record 9 of Set 8 | miri
# Processing Record 10 of Set 8 | lola
# Processing Record 11 of Set 8 | sabha
# Processing Record 12 of Set 8 | edgewater
# Processing Record 13 of Set 8 | laguna
# Processing Record 14 of Set 8 | mahenge
# Processing Record 15 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 8 | narrabri
# Processing Record 17 of Set 8 | ahuimanu
# Processing Record 18 of Set 8 | oktyabrskiy
# Processing Record 19 of Set 8 | acajutla
# Processing Record 20 of Set 8 | sola
# Processing Record 21 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 8 | cherbourg
# Processing Record 23 of Set 8 | eqbaliyeh
# Processing Record 24 of Set 8 | lima
# Processing Record 25 of Set 8 | yerbogachen
# Processing Record 26 of Set 8 | ulaangom
# Processing Record 27 of Set 8 | omboue
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | winnemucca
# Processing Record 30 of Set 8 | houston
# Processing Record 31 of Set 8 | urengoy
# Processing Record 32 of Set 8 | kyshtovka
# Processing Record 33 of Set 8 | lazaro cardenas
# Processing Record 34 of Set 8 | batticaloa
# Processing Record 35 of Set 8 | mercedes
# Processing Record 36 of Set 8 | karratha
# Processing Record 37 of Set 8 | waingapu
# Processing Record 38 of Set 8 | skelleftea
# Processing Record 39 of Set 8 | merauke
# Processing Record 40 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 8 | katobu
# Processing Record 42 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 43 of Set 8 | port macquarie
# Processing Record 44 of Set 8 | meulaboh
# Processing Record 45 of Set 8 | songjianghe
# Processing Record 46 of Set 8 | amapa
# Processing Record 47 of Set 8 | tulun
# Processing Record 48 of Set 8 | kurdzhinovo
# Processing Record 49 of Set 8 | kayanga
# Processing Record 50 of Set 8 | manta
# Processing Record 1 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 2 of Set 9 | richards bay
# Processing Record 3 of Set 9 | chopinzinho
# Processing Record 4 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 9 | taltal
# Processing Record 7 of Set 9 | cajamarca
# Processing Record 8 of Set 9 | isangel
# Processing Record 9 of Set 9 | yokadouma
# Processing Record 10 of Set 9 | aswan
# Processing Record 11 of Set 9 | tarko-sale
# Processing Record 12 of Set 9 | qui nhon
# Processing Record 13 of Set 9 | sobolevo
# Processing Record 14 of Set 9 | anori
# Processing Record 15 of Set 9 | kiunga
# Processing Record 16 of Set 9 | tukrah
# Processing Record 17 of Set 9 | sosnovskoye
# Processing Record 18 of Set 9 | tabuk
# Processing Record 19 of Set 9 | gornopravdinsk
# Processing Record 20 of Set 9 | kontagora
# Processing Record 21 of Set 9 | guarapari
# Processing Record 22 of Set 9 | nara
# Processing Record 23 of Set 9 | neyshabur
# Processing Record 24 of Set 9 | bassila
# Processing Record 25 of Set 9 | bac lieu
# Processing Record 26 of Set 9 | maniitsoq
# Processing Record 27 of Set 9 | ilulissat
# Processing Record 28 of Set 9 | chapais
# Processing Record 29 of Set 9 | fremont
# Processing Record 30 of Set 9 | teguise
# Processing Record 31 of Set 9 | ziarat
# Processing Record 32 of Set 9 | gat
# Processing Record 33 of Set 9 | husavik
# Processing Record 34 of Set 9 | melfi
# Processing Record 35 of Set 9 | kurchum
# Processing Record 36 of Set 9 | koumac
# Processing Record 37 of Set 9 | maykor
# Processing Record 38 of Set 9 | cayenne
# Processing Record 39 of Set 9 | jackson
# Processing Record 40 of Set 9 | terney
# Processing Record 41 of Set 9 | novaya igirma
# Processing Record 42 of Set 9 | prado
# Processing Record 43 of Set 9 | leeton
# Processing Record 44 of Set 9 | ambon
# Processing Record 45 of Set 9 | wadena
# Processing Record 46 of Set 9 | lagoa
# Processing Record 47 of Set 9 | sabang
# Processing Record 48 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 9 | barao de melgaco
# Processing Record 50 of Set 9 | nyurba
# Processing Record 1 of Set 10 | wlodawa
# Processing Record 2 of Set 10 | amga
# Processing Record 3 of Set 10 | san ramon
# Processing Record 4 of Set 10 | vila velha
# Processing Record 5 of Set 10 | santo antonio do ica
# Processing Record 6 of Set 10 | santa cruz cabralia
# Processing Record 7 of Set 10 | gualeguay
# Processing Record 8 of Set 10 | biak
# Processing Record 9 of Set 10 | plettenberg bay
# Processing Record 10 of Set 10 | aykhal
# Processing Record 11 of Set 10 | katsuura
# Processing Record 12 of Set 10 | tongren
# Processing Record 13 of Set 10 | kot putli
# City not found. Skipping...
# Processing Record 14 of Set 10 | russkaya polyana
# Processing Record 15 of Set 10 | stromness
# Processing Record 16 of Set 10 | quatre cocos
# Processing Record 17 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 10 | contamana
# Processing Record 19 of Set 10 | monatele
# City not found. Skipping...
# Processing Record 20 of Set 10 | fare
# Processing Record 21 of Set 10 | poli
# Processing Record 22 of Set 10 | minab
# Processing Record 23 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 10 | weihai
# Processing Record 25 of Set 10 | shizunai
# Processing Record 26 of Set 10 | dzilam gonzalez
# Processing Record 27 of Set 10 | dingli
# Processing Record 28 of Set 10 | saint-augustin
# Processing Record 29 of Set 10 | altamira
# Processing Record 30 of Set 10 | lypnyazhka
# Processing Record 31 of Set 10 | svetlyy
# Processing Record 32 of Set 10 | puerto baquerizo moreno
# Processing Record 33 of Set 10 | kifri
# Processing Record 34 of Set 10 | zemio
# Processing Record 35 of Set 10 | san ignacio
# Processing Record 36 of Set 10 | billings
# Processing Record 37 of Set 10 | parrita
# Processing Record 38 of Set 10 | urumqi
# Processing Record 39 of Set 10 | vagur
# Processing Record 40 of Set 10 | inverell
# Processing Record 41 of Set 10 | bloomfield
# Processing Record 42 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 10 | plouzane
# Processing Record 44 of Set 10 | camana
# Processing Record 45 of Set 10 | tarrafal
# Processing Record 46 of Set 10 | pulaski
# Processing Record 47 of Set 10 | kutum
# Processing Record 48 of Set 10 | goldsboro
# Processing Record 49 of Set 10 | tuy hoa
# Processing Record 50 of Set 10 | ryotsu
# Processing Record 1 of Set 11 | ossora
# Processing Record 2 of Set 11 | mehriz
# Processing Record 3 of Set 11 | kuvandyk
# Processing Record 4 of Set 11 | clive
# Processing Record 5 of Set 11 | northam
# Processing Record 6 of Set 11 | skjervoy
# Processing Record 7 of Set 11 | mwene-ditu
# Processing Record 8 of Set 11 | esperantina
# Processing Record 9 of Set 11 | jiayuguan
# Processing Record 10 of Set 11 | angatuba
# Processing Record 11 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 12 of Set 11 | havoysund
# Processing Record 13 of Set 11 | leticia
# Processing Record 14 of Set 11 | porto novo
# Processing Record 15 of Set 11 | areia branca
# Processing Record 16 of Set 11 | buraydah
# Processing Record 17 of Set 11 | batagay-alyta
# Processing Record 18 of Set 11 | nemuro
# Processing Record 19 of Set 11 | kieta
# Processing Record 20 of Set 11 | olafsvik
# Processing Record 21 of Set 11 | portland
# Processing Record 22 of Set 11 | ust-kulom
# Processing Record 23 of Set 11 | bobrov
# Processing Record 24 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 11 | vostok
# Processing Record 26 of Set 11 | nokaneng
# Processing Record 27 of Set 11 | pietersburg
# Processing Record 28 of Set 11 | churapcha
# Processing Record 29 of Set 11 | mehamn
# Processing Record 30 of Set 11 | ketchikan
# Processing Record 31 of Set 11 | hami
# Processing Record 32 of Set 11 | shakawe
# Processing Record 33 of Set 11 | redmond
# Processing Record 34 of Set 11 | la romana
# Processing Record 35 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 11 | aquiraz
# Processing Record 37 of Set 11 | nantucket
# Processing Record 38 of Set 11 | mayo
# Processing Record 39 of Set 11 | sao joao da barra
# Processing Record 40 of Set 11 | voh
# Processing Record 41 of Set 11 | cam pha
# City not found. Skipping...
# Processing Record 42 of Set 11 | minggang
# Processing Record 43 of Set 11 | flinders
# Processing Record 44 of Set 11 | rorvik
# Processing Record 45 of Set 11 | yuanping
# Processing Record 46 of Set 11 | tari
# Processing Record 47 of Set 11 | dickson
# Processing Record 48 of Set 11 | dubti
# Processing Record 49 of Set 11 | ewo
# Processing Record 50 of Set 11 | kankaanpaa
# Processing Record 1 of Set 12 | opotiki
# Processing Record 2 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 3 of Set 12 | conde
# Processing Record 4 of Set 12 | jumla
# Processing Record 5 of Set 12 | ternate
# Processing Record 6 of Set 12 | banjar
# Processing Record 7 of Set 12 | wentzville
# Processing Record 8 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 12 | torbeyevo
# Processing Record 10 of Set 12 | miles city
# Processing Record 11 of Set 12 | pauini
# Processing Record 12 of Set 12 | ust-nera
# Processing Record 13 of Set 12 | inza
# Processing Record 14 of Set 12 | ayame
# Processing Record 15 of Set 12 | dodge city
# Processing Record 16 of Set 12 | rondonopolis
# Processing Record 17 of Set 12 | romanovka
# Processing Record 18 of Set 12 | isla pucu
# Processing Record 19 of Set 12 | winchester
# Processing Record 20 of Set 12 | brae
# Processing Record 21 of Set 12 | namatanai
# Processing Record 22 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 12 | tabou
# Processing Record 24 of Set 12 | taitung
# Processing Record 25 of Set 12 | ayan
# Processing Record 26 of Set 12 | moctezuma
# Processing Record 27 of Set 12 | sao filipe
# Processing Record 28 of Set 12 | hailar
# Processing Record 29 of Set 12 | kitimat
# Processing Record 30 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 12 | ilyich
# Processing Record 32 of Set 12 | guerrero negro
# Processing Record 33 of Set 12 | milkovo
# Processing Record 34 of Set 12 | chiungutwa
# Processing Record 35 of Set 12 | iskilip
# Processing Record 36 of Set 12 | galashki
# Processing Record 37 of Set 12 | hirado
# Processing Record 38 of Set 12 | kulhudhuffushi
# Processing Record 39 of Set 12 | tzucacab
# Processing Record 40 of Set 12 | ginda
# -----------------------------
# Data Retrieval Complete

# %%
city_data
# Out:
# [{'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 78.84,
#   'Humidity': 78,
#   'Cloudiness': 55,
#   'Wind Speed': 8.01,
#   'Country': 'US',
#   'Date': '2021-10-08 04:00:28',
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 68.56,
#   'Humidity': 95,
#   'Cloudiness': 93,
#   'Wind Speed': 8.01,
#   'Country': 'EC',
#   'Date': '2021-10-08 04:02:20',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 64.31,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:02:20',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 45.3,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:20',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.78,
#   'Humidity': 74,
#   'Cloudiness': 19,
#   'Wind Speed': 9.93,
#   'Country': 'PF',
#   'Date': '2021-10-08 04:02:21',
#   'Current Description': 'few clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 21.87,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:00:48',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 38.14,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.51,
#   'Country': 'AR',
#   'Date': '2021-10-08 04:00:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 47.52,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 7.9,
#   'Country': 'CL',
#   'Date': '2021-10-08 04:01:43',
#   'Current Description': 'clear sky'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.98,
#   'Humidity': 71,
#   'Cloudiness': 12,
#   'Wind Speed': 6.11,
#   'Country': 'PF',
#   'Date': '2021-10-08 04:02:21',
#   'Current Description': 'few clouds'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 70.65,
#   'Humidity': 95,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-10-08 03:57:50',
#   'Current Description': 'mist'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 55.8,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 14.34,
#   'Country': 'NZ',
#   'Date': '2021-10-08 04:02:22',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.95,
#   'Humidity': 79,
#   'Cloudiness': 24,
#   'Wind Speed': 16.87,
#   'Country': 'PF',
#   'Date': '2021-10-08 04:02:22',
#   'Current Description': 'few clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 53.49,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 9.04,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:02:01',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 33.53,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 11.99,
#   'Country': 'CA',
#   'Date': '2021-10-08 03:58:49',
#   'Current Description': 'few clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 75.79,
#   'Humidity': 91,
#   'Cloudiness': 92,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:23',
#   'Current Description': 'light rain'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 84.54,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'LK',
#   'Date': '2021-10-08 04:02:23',
#   'Current Description': 'few clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 30.18,
#   'Humidity': 75,
#   'Cloudiness': 26,
#   'Wind Speed': 6.02,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:02:24',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Baker City',
#   'Lat': 44.7749,
#   'Lng': -117.8344,
#   'Max Temp': 52.93,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:24',
#   'Current Description': 'few clouds'},
#  {'City': 'Vershino-Darasunskiy',
#   'Lat': 52.35,
#   'Lng': 115.5167,
#   'Max Temp': 41.34,
#   'Humidity': 33,
#   'Cloudiness': 90,
#   'Wind Speed': 10.33,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:24',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cardenas',
#   'Lat': 23.0375,
#   'Lng': -81.2047,
#   'Max Temp': 78.06,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 9.64,
#   'Country': 'CU',
#   'Date': '2021-10-08 04:02:25',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 16.27,
#   'Humidity': 86,
#   'Cloudiness': 89,
#   'Wind Speed': 6.91,
#   'Country': 'RU',
#   'Date': '2021-10-08 03:57:57',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 73.6,
#   'Humidity': 48,
#   'Cloudiness': 4,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': '2021-10-08 03:58:22',
#   'Current Description': 'clear sky'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 50.76,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:00:42',
#   'Current Description': 'light rain'},
#  {'City': 'Mao',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 63.16,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'ES',
#   'Date': '2021-10-08 04:02:25',
#   'Current Description': 'clear sky'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 84.33,
#   'Humidity': 68,
#   'Cloudiness': 86,
#   'Wind Speed': 2.66,
#   'Country': 'PG',
#   'Date': '2021-10-08 04:02:26',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 47.03,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 8.5,
#   'Country': 'AR',
#   'Date': '2021-10-08 03:58:30',
#   'Current Description': 'clear sky'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 67.21,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 13.06,
#   'Country': 'MX',
#   'Date': '2021-10-08 04:02:26',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 72.91,
#   'Humidity': 95,
#   'Cloudiness': 5,
#   'Wind Speed': 5.41,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:27',
#   'Current Description': 'clear sky'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 50.4,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'RU',
#   'Date': '2021-10-08 03:58:02',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lalmohan',
#   'Lat': 22.3384,
#   'Lng': 90.7419,
#   'Max Temp': 87.06,
#   'Humidity': 66,
#   'Cloudiness': 57,
#   'Wind Speed': 3.09,
#   'Country': 'BD',
#   'Date': '2021-10-08 04:02:27',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kalmar',
#   'Lat': 56.6616,
#   'Lng': 16.3616,
#   'Max Temp': 45.97,
#   'Humidity': 100,
#   'Cloudiness': 81,
#   'Wind Speed': 0,
#   'Country': 'SE',
#   'Date': '2021-10-08 04:02:27',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 62.02,
#   'Humidity': 88,
#   'Cloudiness': 46,
#   'Wind Speed': 2.95,
#   'Country': 'PE',
#   'Date': '2021-10-08 04:02:28',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 38.26,
#   'Humidity': 59,
#   'Cloudiness': 92,
#   'Wind Speed': 4.5,
#   'Country': 'GL',
#   'Date': '2021-10-08 04:02:28',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 35.46,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.46,
#   'Country': 'GL',
#   'Date': '2021-10-08 04:02:28',
#   'Current Description': 'clear sky'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 44.71,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'CL',
#   'Date': '2021-10-08 03:58:57',
#   'Current Description': 'clear sky'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 78.94,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Date': '2021-10-08 04:00:19',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 67.35,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27,
#   'Country': 'ZA',
#   'Date': '2021-10-08 04:02:29',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lesnoye',
#   'Lat': 58.2841,
#   'Lng': 35.5158,
#   'Max Temp': 34.7,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 5.21,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:29',
#   'Current Description': 'clear sky'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 58.37,
#   'Humidity': 94,
#   'Cloudiness': 28,
#   'Wind Speed': 1.95,
#   'Country': 'US',
#   'Date': '2021-10-08 03:58:57',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 55.47,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 6.11,
#   'Country': 'NZ',
#   'Date': '2021-10-08 04:02:29',
#   'Current Description': 'light rain'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 77.05,
#   'Humidity': 69,
#   'Cloudiness': 78,
#   'Wind Speed': 4.61,
#   'Country': 'CK',
#   'Date': '2021-10-08 04:02:30',
#   'Current Description': 'broken clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 62.1,
#   'Humidity': 59,
#   'Cloudiness': 97,
#   'Wind Speed': 11.54,
#   'Country': 'AU',
#   'Date': '2021-10-08 03:58:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mamlyutka',
#   'Lat': 54.9375,
#   'Lng': 68.5394,
#   'Max Temp': 33.82,
#   'Humidity': 61,
#   'Cloudiness': 9,
#   'Wind Speed': 11.07,
#   'Country': 'KZ',
#   'Date': '2021-10-08 04:01:26',
#   'Current Description': 'clear sky'},
#  {'City': 'Mapiri',
#   'Lat': -15.25,
#   'Lng': -68.1667,
#   'Max Temp': 67.23,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 1.92,
#   'Country': 'BO',
#   'Date': '2021-10-08 04:02:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aksay',
#   'Lat': 47.26,
#   'Lng': 39.87,
#   'Max Temp': 37.62,
#   'Humidity': 63,
#   'Cloudiness': 22,
#   'Wind Speed': 15.39,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:30',
#   'Current Description': 'few clouds'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 65.07,
#   'Humidity': 72,
#   'Cloudiness': 66,
#   'Wind Speed': 7.76,
#   'Country': 'AO',
#   'Date': '2021-10-08 04:02:31',
#   'Current Description': 'broken clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.63,
#   'Humidity': 68,
#   'Cloudiness': 21,
#   'Wind Speed': 11.86,
#   'Country': 'KI',
#   'Date': '2021-10-08 04:02:31',
#   'Current Description': 'few clouds'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 81.18,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 4.25,
#   'Country': 'MX',
#   'Date': '2021-10-08 04:02:31',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manaure',
#   'Lat': 11.7751,
#   'Lng': -72.4445,
#   'Max Temp': 83.21,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 15.79,
#   'Country': 'CO',
#   'Date': '2021-10-08 04:02:31',
#   'Current Description': 'clear sky'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 35.91,
#   'Humidity': 60,
#   'Cloudiness': 26,
#   'Wind Speed': 5.95,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:32',
#   'Current Description': 'scattered clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 67.5,
#   'Humidity': 50,
#   'Cloudiness': 94,
#   'Wind Speed': 8.01,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:02:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 77.74,
#   'Humidity': 85,
#   'Cloudiness': 95,
#   'Wind Speed': 11.79,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:02:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khani',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 47.77,
#   'Humidity': 70,
#   'Cloudiness': 2,
#   'Wind Speed': 5.59,
#   'Country': 'GE',
#   'Date': '2021-10-08 04:02:33',
#   'Current Description': 'clear sky'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 74.64,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:02:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 26.69,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.19,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:02:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 67.08,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 15.35,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:02:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 29.32,
#   'Humidity': 61,
#   'Cloudiness': 9,
#   'Wind Speed': 6.89,
#   'Country': 'GL',
#   'Date': '2021-10-08 04:02:31',
#   'Current Description': 'clear sky'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 82.29,
#   'Humidity': 77,
#   'Cloudiness': 42,
#   'Wind Speed': 8.75,
#   'Country': 'IN',
#   'Date': '2021-10-08 04:02:34',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gwadar',
#   'Lat': 25.1216,
#   'Lng': 62.3254,
#   'Max Temp': 83.32,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Country': 'PK',
#   'Date': '2021-10-08 04:00:56',
#   'Current Description': 'clear sky'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 68.79,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 16.08,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:02:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Xichang',
#   'Lat': 27.8964,
#   'Lng': 102.2634,
#   'Max Temp': 72.7,
#   'Humidity': 75,
#   'Cloudiness': 76,
#   'Wind Speed': 2.57,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:02:35',
#   'Current Description': 'broken clouds'},
#  {'City': 'Zyryanka',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': 29.95,
#   'Humidity': 50,
#   'Cloudiness': 19,
#   'Wind Speed': 10.94,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:35',
#   'Current Description': 'few clouds'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 80.1,
#   'Humidity': 70,
#   'Cloudiness': 60,
#   'Wind Speed': 6.98,
#   'Country': 'JP',
#   'Date': '2021-10-08 04:02:36',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 67.86,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:02:36',
#   'Current Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 32.02,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:36',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Byron Bay',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 76.95,
#   'Humidity': 67,
#   'Cloudiness': 60,
#   'Wind Speed': 11.05,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:02:37',
#   'Current Description': 'broken clouds'},
#  {'City': 'Uglegorsk',
#   'Lat': 49.0833,
#   'Lng': 142.0333,
#   'Max Temp': 53.74,
#   'Humidity': 52,
#   'Cloudiness': 37,
#   'Wind Speed': 11.74,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:37',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 35.71,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 20.13,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:37',
#   'Current Description': 'light rain'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 33.28,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 9.91,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:38',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 35.46,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 17.02,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:38',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 84.38,
#   'Humidity': 66,
#   'Cloudiness': 32,
#   'Wind Speed': 2.33,
#   'Country': 'IN',
#   'Date': '2021-10-08 04:02:38',
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 78.89,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 6.73,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:39',
#   'Current Description': 'clear sky'},
#  {'City': 'Haimen',
#   'Lat': 23.1935,
#   'Lng': 116.6142,
#   'Max Temp': 78.78,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 21.56,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:02:39',
#   'Current Description': 'moderate rain'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 37.56,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:02:40',
#   'Current Description': 'fog'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 35.8,
#   'Humidity': 68,
#   'Cloudiness': 68,
#   'Wind Speed': 27.89,
#   'Country': 'NO',
#   'Date': '2021-10-08 04:02:40',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 58.1,
#   'Humidity': 60,
#   'Cloudiness': 93,
#   'Wind Speed': 14.52,
#   'Country': 'ZA',
#   'Date': '2021-10-08 04:02:40',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thung Song',
#   'Lat': 8.1645,
#   'Lng': 99.6804,
#   'Max Temp': 87.8,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 11.36,
#   'Country': 'TH',
#   'Date': '2021-10-08 04:02:41',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 40.68,
#   'Humidity': 95,
#   'Cloudiness': 1,
#   'Wind Speed': 5.3,
#   'Country': 'CL',
#   'Date': '2021-10-08 04:02:41',
#   'Current Description': 'clear sky'},
#  {'City': 'Aksu',
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 54.54,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 12.37,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:02:41',
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 76.06,
#   'Humidity': 82,
#   'Cloudiness': 6,
#   'Wind Speed': 6.89,
#   'Country': 'TO',
#   'Date': '2021-10-08 04:02:41',
#   'Current Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 70.9,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 23.33,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:02:42',
#   'Current Description': 'clear sky'},
#  {'City': 'Mandeville',
#   'Lat': 18.0417,
#   'Lng': -77.5071,
#   'Max Temp': 77.05,
#   'Humidity': 93,
#   'Cloudiness': 31,
#   'Wind Speed': 3.06,
#   'Country': 'JM',
#   'Date': '2021-10-08 04:02:42',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 36.75,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.43,
#   'Country': 'RO',
#   'Date': '2021-10-08 04:02:42',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 55.9,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 8.46,
#   'Country': 'ZA',
#   'Date': '2021-10-08 04:02:43',
#   'Current Description': 'clear sky'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 83.35,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.4,
#   'Country': 'GT',
#   'Date': '2021-10-08 04:02:43',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lewiston',
#   'Lat': 44.1003,
#   'Lng': -70.2148,
#   'Max Temp': 57.38,
#   'Humidity': 95,
#   'Cloudiness': 2,
#   'Wind Speed': 3.42,
#   'Country': 'US',
#   'Date': '2021-10-08 03:58:15',
#   'Current Description': 'clear sky'},
#  {'City': 'Xingcheng',
#   'Lat': 40.6167,
#   'Lng': 120.7167,
#   'Max Temp': 62.51,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.37,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:02:44',
#   'Current Description': 'clear sky'},
#  {'City': 'Calama',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 53.6,
#   'Humidity': 32,
#   'Cloudiness': 41,
#   'Wind Speed': 2.75,
#   'Country': 'CL',
#   'Date': '2021-10-08 04:00:49',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 33.08,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.88,
#   'Country': 'RU',
#   'Date': '2021-10-08 03:58:31',
#   'Current Description': 'snow'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 52.75,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.25,
#   'Country': 'ZA',
#   'Date': '2021-10-08 03:58:26',
#   'Current Description': 'clear sky'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 55.26,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'NA',
#   'Date': '2021-10-08 04:02:44',
#   'Current Description': 'clear sky'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 63.37,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-08 04:01:40',
#   'Current Description': 'mist'},
#  {'City': 'Taksimo',
#   'Lat': 56.3444,
#   'Lng': 114.8794,
#   'Max Temp': 37.92,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 0.72,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:45',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 71.22,
#   'Humidity': 73,
#   'Cloudiness': 41,
#   'Wind Speed': 7.96,
#   'Country': 'MU',
#   'Date': '2021-10-08 04:02:45',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Poronaysk',
#   'Lat': 49.2167,
#   'Lng': 143.1167,
#   'Max Temp': 55.67,
#   'Humidity': 48,
#   'Cloudiness': 19,
#   'Wind Speed': 14.61,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:45',
#   'Current Description': 'few clouds'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 48.99,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'NZ',
#   'Date': '2021-10-08 04:00:44',
#   'Current Description': 'overcast clouds'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 43.36,
#   'Humidity': 51,
#   'Cloudiness': 7,
#   'Wind Speed': 5.68,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:00:43',
#   'Current Description': 'clear sky'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 69.17,
#   'Humidity': 73,
#   'Cloudiness': 9,
#   'Wind Speed': 8.1,
#   'Country': 'PT',
#   'Date': '2021-10-08 04:02:46',
#   'Current Description': 'clear sky'},
#  {'City': 'San Blas',
#   'Lat': 21.5167,
#   'Lng': -105.2667,
#   'Max Temp': 80.74,
#   'Humidity': 88,
#   'Cloudiness': 4,
#   'Wind Speed': 3.09,
#   'Country': 'MX',
#   'Date': '2021-10-08 04:02:46',
#   'Current Description': 'clear sky'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 85.5,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 11.03,
#   'Country': 'PG',
#   'Date': '2021-10-08 04:02:46',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 69.35,
#   'Humidity': 78,
#   'Cloudiness': 26,
#   'Wind Speed': 9.69,
#   'Country': 'RE',
#   'Date': '2021-10-08 04:02:47',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 71.94,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Date': '2021-10-08 04:01:16',
#   'Current Description': 'clear sky'},
#  {'City': 'Midland',
#   'Lat': 31.9974,
#   'Lng': -102.0779,
#   'Max Temp': 78.49,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2021-10-08 04:00:06',
#   'Current Description': 'clear sky'},
#  {'City': 'Vung Tau',
#   'Lat': 10.346,
#   'Lng': 107.0843,
#   'Max Temp': 82.94,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Country': 'VN',
#   'Date': '2021-10-08 04:02:47',
#   'Current Description': 'light rain'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 46.56,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 14.88,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:00:41',
#   'Current Description': 'light rain'},
#  {'City': 'Auki',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 87.26,
#   'Humidity': 65,
#   'Cloudiness': 29,
#   'Wind Speed': 7.16,
#   'Country': 'SB',
#   'Date': '2021-10-08 04:02:48',
#   'Current Description': 'moderate rain'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 82.56,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 22.35,
#   'Country': 'PW',
#   'Date': '2021-10-08 04:02:48',
#   'Current Description': 'moderate rain'},
#  {'City': 'Bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 50.11,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:02:48',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.37,
#   'Humidity': 65,
#   'Cloudiness': 92,
#   'Wind Speed': 8.08,
#   'Country': 'MV',
#   'Date': '2021-10-08 03:59:15',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 62.67,
#   'Humidity': 95,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:49',
#   'Current Description': 'broken clouds'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 80.89,
#   'Humidity': 78,
#   'Cloudiness': 78,
#   'Wind Speed': 1.92,
#   'Country': 'OM',
#   'Date': '2021-10-08 04:02:49',
#   'Current Description': 'broken clouds'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 77.97,
#   'Humidity': 78,
#   'Cloudiness': 47,
#   'Wind Speed': 11.39,
#   'Country': 'NU',
#   'Date': '2021-10-08 04:02:49',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 24.84,
#   'Humidity': 48,
#   'Cloudiness': 38,
#   'Wind Speed': 4.16,
#   'Country': 'GL',
#   'Date': '2021-10-08 04:02:50',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32.16,
#   'Humidity': 51,
#   'Cloudiness': 17,
#   'Wind Speed': 7.78,
#   'Country': 'GL',
#   'Date': '2021-10-08 04:02:50',
#   'Current Description': 'few clouds'},
#  {'City': 'Tulum',
#   'Lat': 20.2167,
#   'Lng': -87.4667,
#   'Max Temp': 82.98,
#   'Humidity': 87,
#   'Cloudiness': 95,
#   'Wind Speed': 4.92,
#   'Country': 'MX',
#   'Date': '2021-10-08 04:02:24',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Harer',
#   'Lat': 9.3094,
#   'Lng': 42.1258,
#   'Max Temp': 62.22,
#   'Humidity': 81,
#   'Cloudiness': 97,
#   'Wind Speed': 0.83,
#   'Country': 'ET',
#   'Date': '2021-10-08 04:02:50',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 49.87,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'AR',
#   'Date': '2021-10-08 04:00:31',
#   'Current Description': 'clear sky'},
#  {'City': 'Brainerd',
#   'Lat': 46.358,
#   'Lng': -94.2008,
#   'Max Temp': 64.65,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:51',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 66.49,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ZA',
#   'Date': '2021-10-08 03:58:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 60.98,
#   'Humidity': 55,
#   'Cloudiness': 87,
#   'Wind Speed': 15.05,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:02:51',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 61.59,
#   'Humidity': 74,
#   'Cloudiness': 2,
#   'Wind Speed': 9.37,
#   'Country': 'NZ',
#   'Date': '2021-10-08 04:02:51',
#   'Current Description': 'clear sky'},
#  {'City': 'Dovbysh',
#   'Lat': 50.3733,
#   'Lng': 27.9874,
#   'Max Temp': 33.84,
#   'Humidity': 61,
#   'Cloudiness': 9,
#   'Wind Speed': 7.23,
#   'Country': 'UA',
#   'Date': '2021-10-08 04:02:52',
#   'Current Description': 'clear sky'},
#  {'City': 'Buin',
#   'Lat': -33.7333,
#   'Lng': -70.75,
#   'Max Temp': 55.74,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 4.09,
#   'Country': 'CL',
#   'Date': '2021-10-08 04:02:26',
#   'Current Description': 'clear sky'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 43.02,
#   'Humidity': 49,
#   'Cloudiness': 78,
#   'Wind Speed': 7.47,
#   'Country': 'GL',
#   'Date': '2021-10-08 04:02:52',
#   'Current Description': 'broken clouds'},
#  {'City': 'Veshkayma',
#   'Lat': 54.05,
#   'Lng': 47.1333,
#   'Max Temp': 34.61,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 3.06,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:52',
#   'Current Description': 'clear sky'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 81,
#   'Humidity': 78,
#   'Cloudiness': 65,
#   'Wind Speed': 15.03,
#   'Country': 'JP',
#   'Date': '2021-10-08 04:02:53',
#   'Current Description': 'broken clouds'},
#  {'City': 'Epe',
#   'Lat': 6.5841,
#   'Lng': 3.9834,
#   'Max Temp': 75.52,
#   'Humidity': 94,
#   'Cloudiness': 88,
#   'Wind Speed': 1.9,
#   'Country': 'NG',
#   'Date': '2021-10-08 04:02:53',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 83.07,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 7.4,
#   'Country': 'ID',
#   'Date': '2021-10-08 03:58:59',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 24.04,
#   'Humidity': 82,
#   'Cloudiness': 91,
#   'Wind Speed': 5.86,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:53',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 29.26,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 3.98,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:02:54',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hauterive',
#   'Lat': 46.0901,
#   'Lng': 3.4459,
#   'Max Temp': 47.16,
#   'Humidity': 97,
#   'Cloudiness': 9,
#   'Wind Speed': 2.1,
#   'Country': 'FR',
#   'Date': '2021-10-08 04:02:54',
#   'Current Description': 'clear sky'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 23.81,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:54',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 42.93,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:55',
#   'Current Description': 'light rain'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 67.42,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'PT',
#   'Date': '2021-10-08 04:02:55',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 47.35,
#   'Humidity': 86,
#   'Cloudiness': 86,
#   'Wind Speed': 4.83,
#   'Country': 'IT',
#   'Date': '2021-10-08 04:02:55',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lac Du Bonnet',
#   'Lat': 50.2536,
#   'Lng': -96.0612,
#   'Max Temp': 68.59,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:02:55',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 37.29,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:56',
#   'Current Description': 'scattered clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 65.79,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Country': 'ZA',
#   'Date': '2021-10-08 04:00:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Panzhihua',
#   'Lat': 26.5851,
#   'Lng': 101.7128,
#   'Max Temp': 77.54,
#   'Humidity': 70,
#   'Cloudiness': 70,
#   'Wind Speed': 0.6,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:00:35',
#   'Current Description': 'broken clouds'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 77.49,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 13.33,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:02:56',
#   'Current Description': 'clear sky'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 79.74,
#   'Humidity': 79,
#   'Cloudiness': 8,
#   'Wind Speed': 10.04,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:02:57',
#   'Current Description': 'clear sky'},
#  {'City': 'Gizo',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 84.51,
#   'Humidity': 75,
#   'Cloudiness': 81,
#   'Wind Speed': 8.79,
#   'Country': 'SB',
#   'Date': '2021-10-08 04:02:57',
#   'Current Description': 'light rain'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 51.85,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 6.02,
#   'Country': 'NA',
#   'Date': '2021-10-08 04:02:57',
#   'Current Description': 'clear sky'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 62.04,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 12.35,
#   'Country': 'PE',
#   'Date': '2021-10-08 04:02:58',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kabinda',
#   'Lat': -6.1333,
#   'Lng': 24.4833,
#   'Max Temp': 67.96,
#   'Humidity': 78,
#   'Cloudiness': 97,
#   'Wind Speed': 2.82,
#   'Country': 'CD',
#   'Date': '2021-10-08 04:02:58',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Patrocinio',
#   'Lat': -18.9439,
#   'Lng': -46.9925,
#   'Max Temp': 68.41,
#   'Humidity': 82,
#   'Cloudiness': 37,
#   'Wind Speed': 4.65,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:02:58',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Macapa',
#   'Lat': 0.0389,
#   'Lng': -51.0664,
#   'Max Temp': 78.89,
#   'Humidity': 84,
#   'Cloudiness': 58,
#   'Wind Speed': 10.63,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:02:59',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 86.5,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'MX',
#   'Date': '2021-10-08 03:58:25',
#   'Current Description': 'clear sky'},
#  {'City': 'Gaya',
#   'Lat': 24.7833,
#   'Lng': 85,
#   'Max Temp': 85.91,
#   'Humidity': 79,
#   'Cloudiness': 80,
#   'Wind Speed': 4.61,
#   'Country': 'IN',
#   'Date': '2021-10-08 04:02:59',
#   'Current Description': 'mist'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 23.92,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 19.28,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:02:59',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 62.04,
#   'Humidity': 92,
#   'Cloudiness': 21,
#   'Wind Speed': 1.41,
#   'Country': 'US',
#   'Date': '2021-10-08 04:01:53',
#   'Current Description': 'few clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 48.92,
#   'Humidity': 92,
#   'Cloudiness': 2,
#   'Wind Speed': 8.75,
#   'Country': 'CL',
#   'Date': '2021-10-08 04:00:56',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 81.63,
#   'Humidity': 80,
#   'Cloudiness': 18,
#   'Wind Speed': 12.57,
#   'Country': 'GD',
#   'Date': '2021-10-08 04:03:00',
#   'Current Description': 'few clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 67.19,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 4.92,
#   'Country': 'PT',
#   'Date': '2021-10-08 04:03:00',
#   'Current Description': 'clear sky'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 64.54,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 14.94,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:03:00',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 85.73,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 14.65,
#   'Country': 'ID',
#   'Date': '2021-10-08 04:03:01',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tres Arroyos',
#   'Lat': -38.3739,
#   'Lng': -60.2798,
#   'Max Temp': 42.3,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.55,
#   'Country': 'AR',
#   'Date': '2021-10-08 04:03:01',
#   'Current Description': 'clear sky'},
#  {'City': 'Dubbo',
#   'Lat': -32.25,
#   'Lng': 148.6167,
#   'Max Temp': 73.53,
#   'Humidity': 28,
#   'Cloudiness': 56,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:03:01',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 64.44,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 8.23,
#   'Country': 'NZ',
#   'Date': '2021-10-08 04:03:02',
#   'Current Description': 'clear sky'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 83.32,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 10.98,
#   'Country': 'LK',
#   'Date': '2021-10-08 04:03:02',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rincon',
#   'Lat': 32.296,
#   'Lng': -81.2354,
#   'Max Temp': 77.86,
#   'Humidity': 96,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-08 04:01:36',
#   'Current Description': 'broken clouds'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 37.4,
#   'Humidity': 68,
#   'Cloudiness': 97,
#   'Wind Speed': 25.12,
#   'Country': 'NO',
#   'Date': '2021-10-08 04:03:03',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dahra',
#   'Lat': 36.2546,
#   'Lng': 0.8519,
#   'Max Temp': 58.24,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 2.62,
#   'Country': 'DZ',
#   'Date': '2021-10-08 04:03:03',
#   'Current Description': 'clear sky'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 25.88,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:03:03',
#   'Current Description': 'light snow'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 86.05,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:03:03',
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 30.85,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 14.29,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:03:04',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 69.55,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'ES',
#   'Date': '2021-10-08 04:03:04',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lahaina',
#   'Lat': 20.8783,
#   'Lng': -156.6825,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 13.91,
#   'Country': 'US',
#   'Date': '2021-10-08 04:03:05',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Leguizamo',
#   'Lat': -0.1934,
#   'Lng': -74.7819,
#   'Max Temp': 70.43,
#   'Humidity': 95,
#   'Cloudiness': 49,
#   'Wind Speed': 0.67,
#   'Country': 'CO',
#   'Date': '2021-10-08 04:03:05',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kampene',
#   'Lat': -3.6,
#   'Lng': 26.6667,
#   'Max Temp': 67.48,
#   'Humidity': 91,
#   'Cloudiness': 57,
#   'Wind Speed': 1.9,
#   'Country': 'CD',
#   'Date': '2021-10-08 04:03:05',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 58.89,
#   'Humidity': 60,
#   'Cloudiness': 98,
#   'Wind Speed': 8.37,
#   'Country': 'ZA',
#   'Date': '2021-10-08 04:03:05',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jiangyou',
#   'Lat': 31.7667,
#   'Lng': 104.7167,
#   'Max Temp': 64.26,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 2.44,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:03:06',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 31.78,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind Speed': 1.68,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:03:06',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ilabaya',
#   'Lat': -17.4208,
#   'Lng': -70.5133,
#   'Max Temp': 63.68,
#   'Humidity': 63,
#   'Cloudiness': 40,
#   'Wind Speed': 0.43,
#   'Country': 'PE',
#   'Date': '2021-10-08 04:03:06',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Linxia',
#   'Lat': 35.6003,
#   'Lng': 103.2064,
#   'Max Temp': 60.84,
#   'Humidity': 53,
#   'Cloudiness': 87,
#   'Wind Speed': 4.5,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:03:07',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nicoya',
#   'Lat': 10.1483,
#   'Lng': -85.452,
#   'Max Temp': 72.95,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'CR',
#   'Date': '2021-10-08 04:03:07',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 10.27,
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 6.87,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:03:07',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 85.48,
#   'Humidity': 72,
#   'Cloudiness': 94,
#   'Wind Speed': 13.4,
#   'Country': 'SB',
#   'Date': '2021-10-08 04:03:08',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 71.26,
#   'Humidity': 73,
#   'Cloudiness': 38,
#   'Wind Speed': 7,
#   'Country': 'MU',
#   'Date': '2021-10-08 04:01:10',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 64.92,
#   'Humidity': 63,
#   'Cloudiness': 23,
#   'Wind Speed': 6.78,
#   'Country': 'SA',
#   'Date': '2021-10-08 04:03:08',
#   'Current Description': 'few clouds'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 60.82,
#   'Humidity': 54,
#   'Cloudiness': 12,
#   'Wind Speed': 3.15,
#   'Country': 'PT',
#   'Date': '2021-10-08 04:00:31',
#   'Current Description': 'few clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 77.11,
#   'Humidity': 71,
#   'Cloudiness': 71,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2021-10-08 03:59:03',
#   'Current Description': 'light rain'},
#  {'City': 'Marsa Matruh',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 66.43,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 2.08,
#   'Country': 'EG',
#   'Date': '2021-10-08 04:03:09',
#   'Current Description': 'clear sky'},
#  {'City': 'Yuli',
#   'Lat': 9.6989,
#   'Lng': 10.2744,
#   'Max Temp': 74.21,
#   'Humidity': 91,
#   'Cloudiness': 88,
#   'Wind Speed': 1.86,
#   'Country': 'NG',
#   'Date': '2021-10-08 04:03:09',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 85.46,
#   'Humidity': 9,
#   'Cloudiness': 94,
#   'Wind Speed': 8.63,
#   'Country': 'MR',
#   'Date': '2021-10-08 04:03:09',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 75.69,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Country': 'GA',
#   'Date': '2021-10-08 04:03:10',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 79.11,
#   'Humidity': 86,
#   'Cloudiness': 72,
#   'Wind Speed': 3.09,
#   'Country': 'MX',
#   'Date': '2021-10-08 04:03:10',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ambulu',
#   'Lat': -8.345,
#   'Lng': 113.6058,
#   'Max Temp': 85.75,
#   'Humidity': 58,
#   'Cloudiness': 38,
#   'Wind Speed': 9.57,
#   'Country': 'ID',
#   'Date': '2021-10-08 04:03:10',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hokitika',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 54.68,
#   'Humidity': 87,
#   'Cloudiness': 82,
#   'Wind Speed': 5.59,
#   'Country': 'NZ',
#   'Date': '2021-10-08 03:59:12',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hurup',
#   'Lat': 56.7494,
#   'Lng': 8.4195,
#   'Max Temp': 48.49,
#   'Humidity': 90,
#   'Cloudiness': 77,
#   'Wind Speed': 11.63,
#   'Country': 'DK',
#   'Date': '2021-10-08 04:03:11',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pathein',
#   'Lat': 16.7833,
#   'Lng': 94.7333,
#   'Max Temp': 87.1,
#   'Humidity': 69,
#   'Cloudiness': 34,
#   'Wind Speed': 3.96,
#   'Country': 'MM',
#   'Date': '2021-10-08 04:03:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Conceicao Da Barra',
#   'Lat': -18.5933,
#   'Lng': -39.7322,
#   'Max Temp': 73.98,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 10.63,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:03:12',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Homer',
#   'Lat': 59.6425,
#   'Lng': -151.5483,
#   'Max Temp': 45.09,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-08 04:03:12',
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 48.58,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 20.69,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:03:12',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kurilsk',
#   'Lat': 45.2333,
#   'Lng': 147.8833,
#   'Max Temp': 54.03,
#   'Humidity': 68,
#   'Cloudiness': 65,
#   'Wind Speed': 5.79,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:03:13',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ugoofaaru',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 82.72,
#   'Humidity': 78,
#   'Cloudiness': 39,
#   'Wind Speed': 15.57,
#   'Country': 'MV',
#   'Date': '2021-10-08 04:03:13',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bairiki',
#   'Lat': 1.3292,
#   'Lng': 172.9752,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'KI',
#   'Date': '2021-10-08 04:03:13',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dinard',
#   'Lat': 48.6314,
#   'Lng': -2.0614,
#   'Max Temp': 60.35,
#   'Humidity': 82,
#   'Cloudiness': 91,
#   'Wind Speed': 3.44,
#   'Country': 'FR',
#   'Date': '2021-10-08 04:03:14',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pak Phanang',
#   'Lat': 8.3511,
#   'Lng': 100.202,
#   'Max Temp': 88.41,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 13.51,
#   'Country': 'TH',
#   'Date': '2021-10-08 04:03:14',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bouca',
#   'Lat': 6.5105,
#   'Lng': 18.2733,
#   'Max Temp': 68.5,
#   'Humidity': 96,
#   'Cloudiness': 73,
#   'Wind Speed': 1.07,
#   'Country': 'CF',
#   'Date': '2021-10-08 04:03:14',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kuusamo',
#   'Lat': 65.9667,
#   'Lng': 29.1833,
#   'Max Temp': 32.04,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'FI',
#   'Date': '2021-10-08 04:03:14',
#   'Current Description': 'few clouds'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 52.72,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 19.77,
#   'Country': 'FO',
#   'Date': '2021-10-08 04:03:15',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nelson Bay',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 72.75,
#   'Humidity': 63,
#   'Cloudiness': 96,
#   'Wind Speed': 9.4,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:03:15',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 22.3,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Country': 'GL',
#   'Date': '2021-10-08 04:03:15',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severnyy',
#   'Lat': 50.677,
#   'Lng': 36.5532,
#   'Max Temp': 32.04,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:03:16',
#   'Current Description': 'clear sky'},
#  {'City': 'Teguldet',
# ...
#   'Cloudiness': 99,
#   'Wind Speed': 14.56,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:04:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 77.72,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 5.1,
#   'Country': 'SA',
#   'Date': '2021-10-08 04:01:07',
#   'Current Description': 'clear sky'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': 28.02,
#   'Humidity': 53,
#   'Cloudiness': 92,
#   'Wind Speed': 5.44,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 53.38,
#   'Humidity': 77,
#   'Cloudiness': 62,
#   'Wind Speed': 8.12,
#   'Country': 'JP',
#   'Date': '2021-10-08 04:04:34',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kieta',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 84.13,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.73,
#   'Country': 'PG',
#   'Date': '2021-10-08 04:04:35',
#   'Current Description': 'light rain'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 43.77,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 25.97,
#   'Country': 'IS',
#   'Date': '2021-10-08 04:04:35',
#   'Current Description': 'light rain'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 52.61,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-10-08 04:03:23',
#   'Current Description': 'few clouds'},
#  {'City': 'Ust-Kulom',
#   'Lat': 61.6864,
#   'Lng': 53.6902,
#   'Max Temp': 39.56,
#   'Humidity': 82,
#   'Cloudiness': 4,
#   'Wind Speed': 10.78,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:35',
#   'Current Description': 'clear sky'},
#  {'City': 'Bobrov',
#   'Lat': 51.0961,
#   'Lng': 40.0333,
#   'Max Temp': 35.31,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:35',
#   'Current Description': 'clear sky'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 51.28,
#   'Humidity': 53,
#   'Cloudiness': 7,
#   'Wind Speed': 13.22,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Nokaneng',
#   'Lat': -19.6667,
#   'Lng': 22.2667,
#   'Max Temp': 74.35,
#   'Humidity': 46,
#   'Cloudiness': 98,
#   'Wind Speed': 10.71,
#   'Country': 'BW',
#   'Date': '2021-10-08 04:04:36',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pietersburg',
#   'Lat': -23.9045,
#   'Lng': 29.4688,
#   'Max Temp': 48.6,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.71,
#   'Country': 'ZA',
#   'Date': '2021-10-08 04:04:36',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Churapcha',
#   'Lat': 62.0025,
#   'Lng': 132.4325,
#   'Max Temp': 33.71,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.63,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:37',
#   'Current Description': 'light rain'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 39.38,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Country': 'NO',
#   'Date': '2021-10-08 04:04:37',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 46.38,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 25.32,
#   'Country': 'US',
#   'Date': '2021-10-08 04:04:37',
#   'Current Description': 'moderate rain'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 37.76,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 10.74,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:04:38',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shakawe',
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp': 74.95,
#   'Humidity': 41,
#   'Cloudiness': 79,
#   'Wind Speed': 2.44,
#   'Country': 'BW',
#   'Date': '2021-10-08 04:04:38',
#   'Current Description': 'broken clouds'},
#  {'City': 'Redmond',
#   'Lat': 47.674,
#   'Lng': -122.1215,
#   'Max Temp': 50.34,
#   'Humidity': 84,
#   'Cloudiness': 54,
#   'Wind Speed': 2.42,
#   'Country': 'US',
#   'Date': '2021-10-08 04:00:01',
#   'Current Description': 'broken clouds'},
#  {'City': 'La Romana',
#   'Lat': 18.4273,
#   'Lng': -68.9728,
#   'Max Temp': 76.73,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 8.41,
#   'Country': 'DO',
#   'Date': '2021-10-08 04:04:38',
#   'Current Description': 'clear sky'},
#  {'City': 'Aquiraz',
#   'Lat': -3.9014,
#   'Lng': -38.3911,
#   'Max Temp': 80.69,
#   'Humidity': 85,
#   'Cloudiness': 92,
#   'Wind Speed': 11.32,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:04:39',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 63.97,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-08 04:02:06',
#   'Current Description': 'clear sky'},
#  {'City': 'Mayo',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 69.12,
#   'Humidity': 92,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-08 04:04:39',
#   'Current Description': 'clear sky'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 70,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 18.32,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:04:39',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Voh',
#   'Lat': -20.9667,
#   'Lng': 164.7,
#   'Max Temp': 78.76,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 9.62,
#   'Country': 'NC',
#   'Date': '2021-10-08 04:04:39',
#   'Current Description': 'clear sky'},
#  {'City': 'Minggang',
#   'Lat': 32.4586,
#   'Lng': 114.0486,
#   'Max Temp': 60.3,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.67,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:04:40',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 75.79,
#   'Humidity': 59,
#   'Cloudiness': 64,
#   'Wind Speed': 8.01,
#   'Country': 'AU',
#   'Date': '2021-10-08 04:04:40',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rorvik',
#   'Lat': 64.8621,
#   'Lng': 11.2373,
#   'Max Temp': 48.31,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'NO',
#   'Date': '2021-10-08 04:04:41',
#   'Current Description': 'moderate rain'},
#  {'City': 'Yuanping',
#   'Lat': 38.7153,
#   'Lng': 112.7575,
#   'Max Temp': 59.68,
#   'Humidity': 55,
#   'Cloudiness': 27,
#   'Wind Speed': 3.74,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:04:41',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tari',
#   'Lat': 12.4086,
#   'Lng': 4.4914,
#   'Max Temp': 79.05,
#   'Humidity': 71,
#   'Cloudiness': 77,
#   'Wind Speed': 6.46,
#   'Country': 'NG',
#   'Date': '2021-10-08 04:04:42',
#   'Current Description': 'broken clouds'},
#  {'City': 'Dickson',
#   'Lat': 36.077,
#   'Lng': -87.3878,
#   'Max Temp': 67.28,
#   'Humidity': 97,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-10-08 04:04:42',
#   'Current Description': 'few clouds'},
#  {'City': 'Dubti',
#   'Lat': 11.7361,
#   'Lng': 41.0853,
#   'Max Temp': 86.02,
#   'Humidity': 49,
#   'Cloudiness': 78,
#   'Wind Speed': 1.23,
#   'Country': 'ET',
#   'Date': '2021-10-08 04:04:42',
#   'Current Description': 'light rain'},
#  {'City': 'Ewo',
#   'Lat': -0.8725,
#   'Lng': 14.8206,
#   'Max Temp': 72.66,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 3.49,
#   'Country': 'CG',
#   'Date': '2021-10-08 04:04:43',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kankaanpaa',
#   'Lat': 61.8,
#   'Lng': 22.4167,
#   'Max Temp': 50.81,
#   'Humidity': 97,
#   'Cloudiness': 96,
#   'Wind Speed': 4.47,
#   'Country': 'FI',
#   'Date': '2021-10-08 04:04:43',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Opotiki',
#   'Lat': -38.0833,
#   'Lng': 177.2833,
#   'Max Temp': 67.39,
#   'Humidity': 93,
#   'Cloudiness': 72,
#   'Wind Speed': 1.97,
#   'Country': 'NZ',
#   'Date': '2021-10-08 04:04:43',
#   'Current Description': 'broken clouds'},
#  {'City': 'Conde',
#   'Lat': -7.2597,
#   'Lng': -34.9075,
#   'Max Temp': 76.46,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:04:44',
#   'Current Description': 'broken clouds'},
#  {'City': 'Jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 66.94,
#   'Humidity': 60,
#   'Cloudiness': 64,
#   'Wind Speed': 3.76,
#   'Country': 'NP',
#   'Date': '2021-10-08 04:04:44',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ternate',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 84.4,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 9.48,
#   'Country': 'ID',
#   'Date': '2021-10-08 04:04:44',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Banjar',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 80.46,
#   'Humidity': 50,
#   'Cloudiness': 35,
#   'Wind Speed': 1.05,
#   'Country': 'ID',
#   'Date': '2021-10-08 04:04:45',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wentzville',
#   'Lat': 38.8114,
#   'Lng': -90.8529,
#   'Max Temp': 65.88,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 3.85,
#   'Country': 'US',
#   'Date': '2021-10-08 04:04:45',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Torbeyevo',
#   'Lat': 54.0797,
#   'Lng': 43.2473,
#   'Max Temp': 36.34,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 3.02,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:45',
#   'Current Description': 'clear sky'},
#  {'City': 'Miles City',
#   'Lat': 46.4083,
#   'Lng': -105.8406,
#   'Max Temp': 59.5,
#   'Humidity': 35,
#   'Cloudiness': 95,
#   'Wind Speed': 9.24,
#   'Country': 'US',
#   'Date': '2021-10-08 04:00:47',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pauini',
#   'Lat': -7.7136,
#   'Lng': -66.9764,
#   'Max Temp': 79.25,
#   'Humidity': 72,
#   'Cloudiness': 87,
#   'Wind Speed': 2.1,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:04:46',
#   'Current Description': 'moderate rain'},
#  {'City': 'Ust-Nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': 28.26,
#   'Humidity': 53,
#   'Cloudiness': 94,
#   'Wind Speed': 7.81,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:46',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Inza',
#   'Lat': 53.8533,
#   'Lng': 46.3586,
#   'Max Temp': 35.69,
#   'Humidity': 77,
#   'Cloudiness': 2,
#   'Wind Speed': 1.95,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:46',
#   'Current Description': 'clear sky'},
#  {'City': 'Ayame',
#   'Lat': 5.6083,
#   'Lng': -3.1563,
#   'Max Temp': 72.81,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.36,
#   'Country': 'CI',
#   'Date': '2021-10-08 04:04:47',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dodge City',
#   'Lat': 37.7528,
#   'Lng': -100.0171,
#   'Max Temp': 67.64,
#   'Humidity': 67,
#   'Cloudiness': 57,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-08 04:00:17',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rondonopolis',
#   'Lat': -16.4708,
#   'Lng': -54.6356,
#   'Max Temp': 78.4,
#   'Humidity': 78,
#   'Cloudiness': 60,
#   'Wind Speed': 2.98,
#   'Country': 'BR',
#   'Date': '2021-10-08 04:02:58',
#   'Current Description': 'broken clouds'},
#  {'City': 'Romanovka',
#   'Lat': 51.7443,
#   'Lng': 42.7527,
#   'Max Temp': 36.27,
#   'Humidity': 61,
#   'Cloudiness': 25,
#   'Wind Speed': 5.1,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:47',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Isla Pucu',
#   'Lat': -25.3,
#   'Lng': -56.9,
#   'Max Temp': 70.77,
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 5.32,
#   'Country': 'PY',
#   'Date': '2021-10-08 04:04:47',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Winchester',
#   'Lat': 51.0651,
#   'Lng': -1.3187,
#   'Max Temp': 59.49,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 0.4,
#   'Country': 'GB',
#   'Date': '2021-10-08 04:04:48',
#   'Current Description': 'few clouds'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 53.51,
#   'Humidity': 93,
#   'Cloudiness': 35,
#   'Wind Speed': 9.31,
#   'Country': 'GB',
#   'Date': '2021-10-08 04:04:48',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 84.04,
#   'Humidity': 72,
#   'Cloudiness': 93,
#   'Wind Speed': 2.71,
#   'Country': 'PG',
#   'Date': '2021-10-08 04:04:48',
#   'Current Description': 'light rain'},
#  {'City': 'Tabou',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 76.98,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 5.12,
#   'Country': 'CI',
#   'Date': '2021-10-08 04:04:49',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Taitung',
#   'Lat': 22.7583,
#   'Lng': 121.1444,
#   'Max Temp': 86.27,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'TW',
#   'Date': '2021-10-08 04:04:49',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ayan',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 45.63,
#   'Humidity': 39,
#   'Cloudiness': 10,
#   'Wind Speed': 12.95,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:50',
#   'Current Description': 'clear sky'},
#  {'City': 'Moctezuma',
#   'Lat': 29.8,
#   'Lng': -109.6667,
#   'Max Temp': 73.89,
#   'Humidity': 43,
#   'Cloudiness': 86,
#   'Wind Speed': 2.37,
#   'Country': 'MX',
#   'Date': '2021-10-08 04:04:50',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 79.07,
#   'Humidity': 78,
#   'Cloudiness': 21,
#   'Wind Speed': 6.58,
#   'Country': 'CV',
#   'Date': '2021-10-08 04:04:50',
#   'Current Description': 'few clouds'},
#  {'City': 'Hailar',
#   'Lat': 49.2,
#   'Lng': 119.7,
#   'Max Temp': 56.14,
#   'Humidity': 38,
#   'Cloudiness': 79,
#   'Wind Speed': 10.49,
#   'Country': 'CN',
#   'Date': '2021-10-08 04:04:50',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kitimat',
#   'Lat': 54.0524,
#   'Lng': -128.6534,
#   'Max Temp': 43.92,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Country': 'CA',
#   'Date': '2021-10-08 04:04:51',
#   'Current Description': 'moderate rain'},
#  {'City': 'Ilyich',
#   'Lat': 40.8464,
#   'Lng': 68.5067,
#   'Max Temp': 58.69,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Country': 'KZ',
#   'Date': '2021-10-08 04:04:51',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 70.39,
#   'Humidity': 76,
#   'Cloudiness': 97,
#   'Wind Speed': 17.4,
#   'Country': 'MX',
#   'Date': '2021-10-08 04:04:51',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Milkovo',
#   'Lat': 54.7167,
#   'Lng': 158.6167,
#   'Max Temp': 44.46,
#   'Humidity': 42,
#   'Cloudiness': 98,
#   'Wind Speed': 12.12,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:52',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chiungutwa',
#   'Lat': -10.8833,
#   'Lng': 38.9833,
#   'Max Temp': 69.31,
#   'Humidity': 84,
#   'Cloudiness': 11,
#   'Wind Speed': 2.71,
#   'Country': 'TZ',
#   'Date': '2021-10-08 04:04:52',
#   'Current Description': 'few clouds'},
#  {'City': 'Iskilip',
#   'Lat': 40.7353,
#   'Lng': 34.4739,
#   'Max Temp': 47.68,
#   'Humidity': 82,
#   'Cloudiness': 2,
#   'Wind Speed': 4.07,
#   'Country': 'TR',
#   'Date': '2021-10-08 04:04:52',
#   'Current Description': 'clear sky'},
#  {'City': 'Galashki',
#   'Lat': 43.1136,
#   'Lng': 44.9894,
#   'Max Temp': 41.95,
#   'Humidity': 87,
#   'Cloudiness': 77,
#   'Wind Speed': 0.81,
#   'Country': 'RU',
#   'Date': '2021-10-08 04:04:53',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hirado',
#   'Lat': 33.3597,
#   'Lng': 129.5531,
#   'Max Temp': 79.36,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 7.76,
#   'Country': 'JP',
#   'Date': '2021-10-08 04:04:53',
#   'Current Description': 'clear sky'},
#  {'City': 'Kulhudhuffushi',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp': 82.51,
#   'Humidity': 80,
#   'Cloudiness': 54,
#   'Wind Speed': 16.22,
#   'Country': 'MV',
#   'Date': '2021-10-08 04:04:53',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tzucacab',
#   'Lat': 20.0667,
#   'Lng': -89.05,
#   'Max Temp': 74.01,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'MX',
#   'Date': '2021-10-08 04:04:54',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ginda',
#   'Lat': 30.6945,
#   'Lng': 78.4932,
#   'Max Temp': 69.55,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Country': 'IN',
#   'Date': '2021-10-08 04:04:54',
#   'Current Description': 'clear sky'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kahului  20.8947 -156.4700     78.84        78          55
# 1      Puerto Ayora  -0.7393  -90.3518     68.56        95          93
# 2     Mount Gambier -37.8333  140.7667     64.31        48          75
# 3            Kodiak  57.7900 -152.4072     45.30        86         100
# 4           Rikitea -23.1203 -134.9692     73.78        74          19
# ..              ...      ...       ...       ...       ...         ...
# 542        Galashki  43.1136   44.9894     41.95        87          77
# 543          Hirado  33.3597  129.5531     79.36        70           0
# 544  Kulhudhuffushi   6.6221   73.0700     82.51        80          54
# 545        Tzucacab  20.0667  -89.0500     74.01        96         100
# 546           Ginda  30.6945   78.4932     69.55        68           0
#
#      Wind Speed Country                 Date Current Description
# 0          8.01      US  2021-10-08 04:00:28       broken clouds
# 1          8.01      EC  2021-10-08 04:02:20     overcast clouds
# 2         20.71      AU  2021-10-08 04:02:20       broken clouds
# 3         10.00      US  2021-10-08 04:02:20     overcast clouds
# 4          9.93      PF  2021-10-08 04:02:21          few clouds
# ..          ...     ...                  ...                 ...
# 542        0.81      RU  2021-10-08 04:04:53       broken clouds
# 543        7.76      JP  2021-10-08 04:04:53           clear sky
# 544       16.22      MV  2021-10-08 04:04:53       broken clouds
# 545        1.14      MX  2021-10-08 04:04:54     overcast clouds
# 546        4.18      IN  2021-10-08 04:04:54           clear sky
#
# [547 rows x 10 columns]

# %%
csv_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(csv_data_file, index_label = "City ID")
